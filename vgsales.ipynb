# %%
# Importing libraries
import pandas as pd
import numpy as np

# Read csv file into a pandas dataframe
df = pd.read_csv("vgsales.csv")

df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            160
# Genre             0
# Publisher        30
# NA_Sales          0
# EU_Sales         16
# JP_Sales         19
# Other_Sales      15
# Global_Sales     21
# dtype: int64

# %%
df['Year'].fillna(df.Year.mode()[0],inplace=True)
df['Publisher'].fillna('MisterX',inplace=True)
#df['NA_Sales'] =  pd.to_numeric(df['NA_Sales'],errors='coerce')
df['NA_Sales'].fillna(df.NA_Sales.mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher        0
# NA_Sales         0
# EU_Sales        16
# JP_Sales        19
# Other_Sales     15
# Global_Sales    21
# dtype: int64

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = df.select_dtypes(include=numerics)
newdf
# Out:
#        Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0         1     41.49     29.02      3.77         8.46         82.74
# 1         2     29.08      3.58      6.81         0.77         40.24
# 2         3     15.85     12.88      3.79         3.31         35.82
# 3         4     15.75     11.01      3.28         2.96         33.00
# 4         5     11.27      8.89     10.22         1.00         31.37
# 5         6     23.20      2.26      4.22         0.58         30.26
# 6         7     11.38      9.23      6.50         2.90         30.01
# 7         8     14.03      9.20      2.93         2.85         29.02
# 8         9     14.59      7.06      4.70         2.26         28.62
# 9        10     26.93      0.63      0.28         0.47         28.31
# 10       11      9.07     11.00      1.93         2.75         24.76
# 11       12      9.81      7.57      4.13         1.92         23.42
# 12       13      9.00      6.18      7.20         0.71         23.10
# ...

# %%
import pandas as pd
from sklearn import preprocessing

 
dff = pd.DataFrame(newdf)
dff
cols=newdf.columns
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(dff)
df_normalized = pd.DataFrame(np_scaled, columns = cols)
df_normalized
# Out:
#         Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     0.0000  1.000000  1.000000  0.368885     0.800378      1.000000
# 1     0.0001  0.700892  0.123363  0.666341     0.072848      0.486032
# 2     0.0002  0.382020  0.443832  0.370841     0.313150      0.432580
# 3     0.0003  0.379610  0.379394  0.320939     0.280038      0.398476
# 4     0.0004  0.271632  0.306340  1.000000     0.094607      0.378764
# 5     0.0005  0.559171  0.077877  0.412916     0.054872      0.365340
# 6     0.0006  0.274283  0.318057  0.636008     0.274361      0.362317
# 7     0.0007  0.338154  0.317023  0.286693     0.269631      0.350345
# 8     0.0008  0.351651  0.243280  0.459883     0.213813      0.345507
# 9     0.0009  0.649072  0.021709  0.027397     0.044465      0.341758
# 10    0.0010  0.218607  0.379049  0.188845     0.260170      0.298827
# 11    0.0011  0.236443  0.260855  0.404110     0.181646      0.282622
# ...

# %%
newdff=(newdf-newdf.mean())/newdf.std()
newdff
# Out:
#           Rank   NA_Sales   EU_Sales   JP_Sales  Other_Sales  Global_Sales
# 0    -1.731946  40.214559  45.314031   9.300124    35.176938     42.249720
# 1    -1.731600  28.061715   5.263423  17.043274     2.904008     20.320463
# 2    -1.731253  15.105863  19.904565   9.351065    13.563727     18.039821
# 3    -1.730907  15.007935  16.960593   8.052050    12.094868     16.584750
# 4    -1.730560  10.620768  13.623043  25.728848     3.869258     15.743699
# 5    -1.730214  22.303558   3.185325  10.446314     2.106627     15.170958
# 6    -1.729868  10.728489  14.158310  16.253677    11.843064     15.041962
# 7    -1.729521  13.323576  14.111081   7.160569    11.633227     14.531140
# 8    -1.729175  13.871972  10.742044  11.668916     9.157150     14.324747
# 9    -1.728828  25.956267   0.619190   0.410783     1.644986     14.164792
# 10   -1.728482   8.466356  16.944850   4.613480    11.213553     12.333054
# ...

# %%
newdff.mean()
# Out:
# Rank           -3.549338e-17
# NA_Sales        7.964873e-16
# EU_Sales       -3.329825e-14
# JP_Sales       -2.479407e-14
# Other_Sales     4.437929e-14
# Global_Sales   -3.256151e-16
# dtype: float64

# %%
newdff.std()
# Out:
# Rank            1.0
# NA_Sales        1.0
# EU_Sales        1.0
# JP_Sales        1.0
# Other_Sales     1.0
# Global_Sales    1.0
# dtype: float64

# %%
from numpy.random import seed
from numpy.random import randn
from matplotlib import pyplot
# %matplotlib inline

pyplot.hist(newdff)
pyplot.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

platGenre = pd.crosstab(df.Platform,df.Genre)
platGenreTotal = platGenre.sum(axis=1).sort_values(ascending = False)
plt.figure(figsize=(8,6))
sns.barplot(y = platGenreTotal.index, x = platGenreTotal.values, orient='h')
plt.ylabel = "Platform"
plt.xlabel = "The amount of games"
plt.show()

# %%
y = df.groupby(['Year']).sum()
y = y['Global_Sales']
#x = y.index.astype(int)
x = y.index
plt.figure(figsize=(12,8))
ax = sns.barplot(y = y, x = x)
ax.set_xlabel(xlabel='$ Millions', fontsize=16)
ax.set_xticklabels(labels = x, fontsize=12, rotation=50)
ax.set_ylabel(ylabel='Year', fontsize=16)
ax.set_title(label='Game Sales in $ Millions Per Year', fontsize=20)
plt.show();

# %%
table = df.pivot_table('Global_Sales', columns='Year', index='Name')
q = table.quantile(0.90)
data = table[table < q]
years = table.columns

plt.figure(figsize=(12,8))
ax = sns.boxplot(data=data)
ax.set_xticklabels(labels=years, fontsize=12, rotation=50)
ax.set_xlabel(xlabel='Year', fontsize=16)
ax.set_ylabel(ylabel='Revenue Per Game in $ Millions', fontsize=16)
ax.set_title(label='Distribution of Revenue Per Game by Year in $ Millions', fontsize=20)
plt.show()
plt.show()

# %%
import seaborn as sns

 
# use the function regplot to make a scatterplot
sns.regplot(x=newdf["NA_Sales"], y=newdf["EU_Sales"])

 
# Without regression fit:
sns.regplot(x=newdf["NA_Sales"], y=newdf["EU_Sales"],fit_reg=False)

# %%
# use the function regplot to make a scatterplot
sns.regplot(x=newdf["JP_Sales"], y=newdf["Global_Sales"])

 
# Without regression fit:
sns.regplot(x=newdf["JP_Sales"], y=newdf["Global_Sales"],fit_reg=False)

# %%
# use the function regplot to make a scatterplot
sns.regplot(x=newdf["NA_Sales"], y=newdf["Global_Sales"])

 
# Without regression fit:
sns.regplot(x=newdf["NA_Sales"], y=newdf["Global_Sales"],fit_reg=False)

# %%
# use the function regplot to make a scatterplot
sns.regplot(x=newdf["EU_Sales"], y=newdf["Global_Sales"])

 
# Without regression fit:
sns.regplot(x=newdf["EU_Sales"], y=newdf["Global_Sales"],fit_reg=False)

# %%
from scipy.stats import norm
from math import sqrt,floor
import random 
x = random.randint(1,500)
y = random.randint(500,1000)
a = df[x:y]['Global_Sales']

def one_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha):
    actual_z = abs(norm.ppf(alpha))
    hypo_z = (sample_mean - pop_mean) / (std_dev/sqrt(sample_size))
    print('actual z value :', actual_z)
    print('hypothesis z value :', hypo_z, '\n')
    if hypo_z >= actual_z:
        return True
    else:
        return False
    

alpha = 0.05
sample_mean = a.mean()
pop_mean = df['Global_Sales'].mean()
sample_size =y - x
std_dev =a.std()



print('H0 : μ <=', pop_mean)
print('H1 : μ >', pop_mean)
print('alpha value is :', alpha, '\n')

reject = one_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha)
if reject:
    print('Reject NULL hypothesis')
else:
    print('Failed to reject NULL hypothesis')
# Out:
# H0 : μ <= 0.8579213764129309
# H1 : μ > 0.8579213764129309
# alpha value is : 0.05
#
# actual z value : 1.6448536269514729
# hypothesis z value : 130.0307772784743
#
# Reject NULL hypothesis

# %%
print(df['Global_Sales'][1:4])
# Out:
# 1    40.24
# 2    35.82
# 3    33.00
# Name: Global_Sales, dtype: float64

# %%
np.corrcoef(x=newdf['EU_Sales'],  y=newdf['JP_Sales'])
# Out:
# array([[1.        , 0.41651498],
#        [0.41651498, 1.        ]])

# %%
np.corrcoef(x=newdf['EU_Sales'],  y=newdf['Global_Sales'])
# Out:
# array([[1.        , 0.89787844],
#        [0.89787844, 1.        ]])

# %%
np.corrcoef(x=newdf['JP_Sales'],  y=newdf['Global_Sales'])
# Out:
# array([[1.       , 0.5985765],
#        [0.5985765, 1.       ]])

# %%
sns.heatmap(newdf.corr())
